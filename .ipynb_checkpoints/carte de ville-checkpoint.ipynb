# %%
## Importation des bibliothèques géospatiales et de visualisation
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Chargement des données géospatiales
dff = gpd.read_file('map.geojson')
dff.head()
# Out:
#                   timestamp version  changeset          user      uid
# 0 2023-03-07 07:51:58+00:00     125  133391758  nona mostafa  9515203  \
# 1 2020-11-24 01:06:46+00:00      21   94668480  MustafaQasim  9535554
# 2 2020-11-24 01:06:46+00:00      14   94668480  MustafaQasim  9535554
# 3 2020-11-24 01:06:46+00:00      17   94668480  MustafaQasim  9535554
# 4 2023-03-08 20:05:15+00:00      17  133454222  Maarten Deen     9176
#
#   addr:city addr:full addr:housenumber addr:place addr:postcode  ...
# 0       NaN       NaN              NaN        NaN           NaN  ...  \
# 1       NaN       NaN              NaN        NaN           NaN  ...
# 2       NaN       NaN              NaN        NaN           NaN  ...
# 3       NaN       NaN              NaN        NaN           NaN  ...
# 4       NaN       NaN              NaN        NaN           NaN  ...
#
#       to:ar train tunnel      type usage voltage  wikidata
# 0       NaN   NaN    NaN     route   NaN     NaN       NaN  \
# 1       NaN   NaN    NaN  boundary   NaN     NaN  Q2627209
# 2       NaN   NaN    NaN  boundary   NaN     NaN       NaN
# 3       NaN   NaN    NaN  boundary   NaN     NaN       NaN
# 4  ابن جرير   NaN    NaN     route   NaN     NaN       NaN
#
#                wikipedia                id
# 0                    NaN  relation/1827899  \
# 1  fr:Youssoufia (Maroc)  relation/2827881
# 2                    NaN  relation/2827882
# 3                    NaN  relation/2827886
# 4                    NaN  relation/4508663
#
#                                             geometry
# 0  MULTILINESTRING ((-8.55595 32.29040, -8.55577 ...
# 1  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 2  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 3  POLYGON ((-8.53174 32.22420, -8.52178 32.23045...
# 4  LINESTRING (-8.37457 32.27888, -8.37760 32.279...
#
# [5 rows x 89 columns]

# %%
# Sélection des colonnes 
selected_columns = ['name', 'geometry']
dff = dff[selected_columns]

# %%
# Suppression des valeurs manquantes (NaN)
dff = dff.dropna()

# %%
dff.head()
# Out:
#                                 name
# 0                 Route Nationale 11  \
# 1        Youssoufia ⵢⵓⵙⴼⵉⵢⴰ اليوسفية
# 2                    Esbiaat اسبيعات
# 3                 El Gantour الڭنطور
# 4  Safi - Ben Guerir أسفي - ابن جرير
#
#                                             geometry
# 0  MULTILINESTRING ((-8.55595 32.29040, -8.55577 ...
# 1  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 2  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 3  POLYGON ((-8.53174 32.22420, -8.52178 32.23045...
# 4  LINESTRING (-8.37457 32.27888, -8.37760 32.279...

# %%
import folium
from folium.plugins import MarkerCluster

# Assuming 'dff' is your GeoDataFrame containing the data

# Step 1: Get the centroid of the geometries and use it as the map center
map_center = [dff.geometry.centroid.y.mean(), dff.geometry.centroid.x.mean()]

# Step 2: Create the Folium map centered at the centroid
m = folium.Map(location=map_center, zoom_start=14)

# Step 3: Add the geometries to the map using MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

# Step 4: Add each geometry as a marker to the MarkerCluster with a popup label
for idx, row in dff.iterrows():
    name = row['name']
    # Use the centroid of the geometry as the location for the marker
    lat, lon = row.geometry.centroid.y, row.geometry.centroid.x
    folium.Marker([lat, lon], popup=name).add_to(marker_cluster)

# Step 5: Display the map
m.save('map.html')  # Save the map to an HTML file
m  # Display the map in Jupyter Notebook
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_24828\3781308186.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_center = [dff.geometry.centroid.y.mean(), dff.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92eb2997f6c7c6f4cdb873716a1eff4c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92eb2997f6c7c6f4cdb873716a1eff4c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92eb2997f6c7c6f4cdb873716a1eff4c = L.map(
#                 &quot;map_92eb2997f6c7c6f4cdb873716a1eff4c&quot;,
#                 {
#                     center: [32.244340001398626, -8.537424192993926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8de036ce4eb259b6430cbca03e87954d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_92eb2997f6c7c6f4cdb873716a1eff4c);
#
#
#             var marker_cluster_1ae8a33c20be59a60386ea4aa75442fe = L.markerClusterGroup(
#                 {}
#             );
#             map_92eb2997f6c7c6f4cdb873716a1eff4c.addLayer(marker_cluster_1ae8a33c20be59a60386ea4aa75442fe);
#
#
#             var marker_929f5cc585f612496d974fe1e43c106c = L.marker(
#                 [32.19700293421064, -8.571188877341564],
#                 {}
#             ).addTo(marker_cluster_1ae8a33c20be59a60386ea4aa75442fe);
#
#
#         var popup_a9ca268baa2dac65059c9b6fda3930b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_36d9a676f755c151f17348e3905102f6 = $(`&lt;div id=&quot;html_36d9a676f755c151f17348e3905102f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route Nationale 11&lt;/div&gt;`)[0];
#                 popup_a9ca268baa2dac65059c9b6fda3930b6.setContent(html_36d9a676f755c151f17348e3905102f6);
#
#
#
#         marker_929f5cc585f612496d974fe1e43c106c.bindPopup(popup_a9ca268baa2dac65059c9b6fda3930b6)
#         ;
#
#
#
#
#             var marker_80cf3ab17d6a861807d7a1bacc262607 = L.marker(
#                 [32.24440789266327, -8.53325946041516],
#                 {}
#             ).addTo(marker_cluster_1ae8a33c20be59a60386ea4aa75442fe);
#
#
#         var popup_4765892e74e644aaad5fb7385570ffb0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_946013320154b4df95ed32a35793c5c4 = $(`&lt;div id=&quot;html_946013320154b4df95ed32a35793c5c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Youssoufia ⵢⵓⵙⴼⵉⵢⴰ اليوسفية&lt;/div&gt;`)[0];
#                 popup_4765892e74e644aaad5fb7385570ffb0.setContent(html_946013320154b4df95ed32a35793c5c4);
#
#
#
#         marker_80cf3ab17d6a861807d7a1bacc262607.bindPopup(popup_4765892e74e644aaad5fb7385570ffb0)
#         ;
#
#
#
#
#             var marker_b3b01a1cd3f09f1126865d2338c0c73e = L.marker(
#                 [32.24165360257278, -8.54707830493086],
#                 {}
#             ).addTo(marker_cluster_1ae8a33c20be59a60386ea4aa75442fe);
#
#
#         var popup_970ccfd2c1a584a3e88b395125b71cb8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_03a71c1b852766f814a8716150626549 = $(`&lt;div id=&quot;html_03a71c1b852766f814a8716150626549&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Esbiaat اسبيعات&lt;/div&gt;`)[0];
#                 popup_970ccfd2c1a584a3e88b395125b71cb8.setContent(html_03a71c1b852766f814a8716150626549);
#
#
#
#         marker_b3b01a1cd3f09f1126865d2338c0c73e.bindPopup(popup_970ccfd2c1a584a3e88b395125b71cb8)
#         ;
#
#
#
#
#             var marker_e1bd4e356c25492d4a6a36bf2973f73e = L.marker(
#                 [32.246641249418126, -8.52205424646547],
#                 {}
#             ).addTo(marker_cluster_1ae8a33c20be59a60386ea4aa75442fe);
#
#
#         var popup_92f7b5dd86fb3a3b3d01227e49d06f58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a47c0995d267ad6eb3a70ce42801a32d = $(`&lt;div id=&quot;html_a47c0995d267ad6eb3a70ce42801a32d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Gantour الڭنطور&lt;/div&gt;`)[0];
#                 popup_92f7b5dd86fb3a3b3d01227e49d06f58.setContent(html_a47c0995d267ad6eb3a70ce42801a32d);
#
#
#
#         marker_e1bd4e356c25492d4a6a36bf2973f73e.bindPopup(popup_92f7b5dd86fb3a3b3d01227e49d06f58)
#         ;
#
#
#
#
#             var marker_0023a0adc4797be75e523ecf7b06720c = L.marker(

# %%
# Chargement des données géospatiales
df = gpd.read_file('map_points.geojson')
df
# Out:
#                       name                   geometry
# 0                  Youcode  POINT (-8.52180 32.24755)
# 1               Gare train  POINT (-8.53454 32.24743)
# 2                   Eglise  POINT (-8.52766 32.24389)
# 3         Pharmacie Lahdir  POINT (-8.53237 32.24893)
# 4   Pharmacie Louis Gentil  POINT (-8.52834 32.24615)
# 5        Pharmacie Al Ouma  POINT (-8.53410 32.24584)
# 6   Pharmacie Minicipalité  POINT (-8.53457 32.24465)
# 7        Pharmacie Kachkat  POINT (-8.53327 32.24581)
# 8     Pharmacie Orphelinat  POINT (-8.53180 32.24461)
# 9          Pharmacie Ahmar  POINT (-8.53544 32.24186)
# 10       Pharmacie du souk  POINT (-8.53793 32.23999)
# 11       Pharmacie Moderne  POINT (-8.53715 32.24158)
# 12      Pharmacie Ibn Sina  POINT (-8.54225 32.23990)
# 13               Gare Taxi  POINT (-8.53939 32.23995)
# 14                Gare Bus  POINT (-8.54006 32.23954)

# %%
import folium
from folium.plugins import MarkerCluster

# Step 1: Create a map centered at the mean of the points
m = folium.Map(location=[df.geometry.y.mean(), df.geometry.x.mean()], zoom_start=14)

# Step 2: Create a MarkerCluster to group the points
marker_cluster = MarkerCluster().add_to(m)

# Step 3: Add each point to the MarkerCluster with a popup label
for idx, row in df.iterrows():
    name = row['name']
    lat, lon = row.geometry.y, row.geometry.x
    folium.Marker([lat, lon], popup=name).add_to(marker_cluster)

# Step 4: Display the map
m.save('map_points.html')  # Save the map to an HTML file
m  # Display the map in Jupyter Notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9887e800f73f0d65d75d5a0fdae007e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9887e800f73f0d65d75d5a0fdae007e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9887e800f73f0d65d75d5a0fdae007e = L.map(
#                 &quot;map_d9887e800f73f0d65d75d5a0fdae007e&quot;,
#                 {
#                     center: [32.243844854948335, -8.534044301374548],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5aadf4233345a7c0219934324cb82862 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9887e800f73f0d65d75d5a0fdae007e);
#
#
#             var marker_cluster_d58d2ea01f9a81ba4380cf488bc438fd = L.markerClusterGroup(
#                 {}
#             );
#             map_d9887e800f73f0d65d75d5a0fdae007e.addLayer(marker_cluster_d58d2ea01f9a81ba4380cf488bc438fd);
#
#
#             var marker_63cec8ddca3ba31a94c8c108acf13083 = L.marker(
#                 [32.24754670596461, -8.521804293657084],
#                 {}
#             ).addTo(marker_cluster_d58d2ea01f9a81ba4380cf488bc438fd);
#
#
#         var popup_2cfe060ca499ff2981819093d93f0998 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_29d23485cf544f2db5a68c50634629d7 = $(`&lt;div id=&quot;html_29d23485cf544f2db5a68c50634629d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Youcode&lt;/div&gt;`)[0];
#                 popup_2cfe060ca499ff2981819093d93f0998.setContent(html_29d23485cf544f2db5a68c50634629d7);
#
#
#
#         marker_63cec8ddca3ba31a94c8c108acf13083.bindPopup(popup_2cfe060ca499ff2981819093d93f0998)
#         ;
#
#
#
#
#             var marker_0bebd678ecde3122317a985fd749134b = L.marker(
#                 [32.24742511509025, -8.534540710722297],
#                 {}
#             ).addTo(marker_cluster_d58d2ea01f9a81ba4380cf488bc438fd);
#
#
#         var popup_305bd06fbb607308dd0c2f3337cee10a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_634e2f0a0d05977fc2091c140ccbb01a = $(`&lt;div id=&quot;html_634e2f0a0d05977fc2091c140ccbb01a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gare train&lt;/div&gt;`)[0];
#                 popup_305bd06fbb607308dd0c2f3337cee10a.setContent(html_634e2f0a0d05977fc2091c140ccbb01a);
#
#
#
#         marker_0bebd678ecde3122317a985fd749134b.bindPopup(popup_305bd06fbb607308dd0c2f3337cee10a)
#         ;
#
#
#
#
#             var marker_a24dd9d50e46c2bf690e684ed5aa09e8 = L.marker(
#                 [32.24389444948477, -8.527658547545968],
#                 {}
#             ).addTo(marker_cluster_d58d2ea01f9a81ba4380cf488bc438fd);
#
#
#         var popup_c591f66e67f2f540ee74becbe08ef6d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a039cdfca64752e100a09a6e73aa708 = $(`&lt;div id=&quot;html_5a039cdfca64752e100a09a6e73aa708&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eglise&lt;/div&gt;`)[0];
#                 popup_c591f66e67f2f540ee74becbe08ef6d1.setContent(html_5a039cdfca64752e100a09a6e73aa708);
#
#
#
#         marker_a24dd9d50e46c2bf690e684ed5aa09e8.bindPopup(popup_c591f66e67f2f540ee74becbe08ef6d1)
#         ;
#
#
#
#
#             var marker_f3ecf155d57c9c393187c94eef3f25d1 = L.marker(
#                 [32.248929704096554, -8.532369927192036],
#                 {}
#             ).addTo(marker_cluster_d58d2ea01f9a81ba4380cf488bc438fd);
#
#
#         var popup_c1a8cc36f060f4eb4d404dd49603df6d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cabe77da13562d95295ccef4275b1c90 = $(`&lt;div id=&quot;html_cabe77da13562d95295ccef4275b1c90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Lahdir&lt;/div&gt;`)[0];
#                 popup_c1a8cc36f060f4eb4d404dd49603df6d.setContent(html_cabe77da13562d95295ccef4275b1c90);
#
#
#
#         marker_f3ecf155d57c9c393187c94eef3f25d1.bindPopup(popup_c1a8cc36f060f4eb4d404dd49603df6d)
#         ;
#
#
#
#
#             var marker_2c9bae93590aef9afc6410650246d6ed = L.marker(
#                 [32.24615448176418, -8.528
