# %%
## Importation des bibliothèques géospatiales et de visualisation
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# Chargement des données géospatiales
dff = gpd.read_file('map.geojson')
dff.head()
# Out:
#                   timestamp version  changeset          user      uid
# 0 2023-03-07 07:51:58+00:00     125  133391758  nona mostafa  9515203  \
# 1 2020-11-24 01:06:46+00:00      21   94668480  MustafaQasim  9535554
# 2 2020-11-24 01:06:46+00:00      14   94668480  MustafaQasim  9535554
# 3 2020-11-24 01:06:46+00:00      17   94668480  MustafaQasim  9535554
# 4 2023-03-08 20:05:15+00:00      17  133454222  Maarten Deen     9176
#
#   addr:city addr:full addr:housenumber addr:place addr:postcode  ...
# 0       NaN       NaN              NaN        NaN           NaN  ...  \
# 1       NaN       NaN              NaN        NaN           NaN  ...
# 2       NaN       NaN              NaN        NaN           NaN  ...
# 3       NaN       NaN              NaN        NaN           NaN  ...
# 4       NaN       NaN              NaN        NaN           NaN  ...
#
#       to:ar train tunnel      type usage voltage  wikidata
# 0       NaN   NaN    NaN     route   NaN     NaN       NaN  \
# 1       NaN   NaN    NaN  boundary   NaN     NaN  Q2627209
# 2       NaN   NaN    NaN  boundary   NaN     NaN       NaN
# 3       NaN   NaN    NaN  boundary   NaN     NaN       NaN
# 4  ابن جرير   NaN    NaN     route   NaN     NaN       NaN
#
#                wikipedia                id
# 0                    NaN  relation/1827899  \
# 1  fr:Youssoufia (Maroc)  relation/2827881
# 2                    NaN  relation/2827882
# 3                    NaN  relation/2827886
# 4                    NaN  relation/4508663
#
#                                             geometry
# 0  MULTILINESTRING ((-8.55595 32.29040, -8.55577 ...
# 1  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 2  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 3  POLYGON ((-8.53174 32.22420, -8.52178 32.23045...
# 4  LINESTRING (-8.37457 32.27888, -8.37760 32.279...
#
# [5 rows x 89 columns]

# %%
# Sélection des colonnes 
selected_columns = ['name', 'geometry']
dff = dff[selected_columns]

# %%
# Suppression des valeurs manquantes (NaN)
dff = dff.dropna()

# %%
dff.head()
# Out:
#                                 name
# 0                 Route Nationale 11  \
# 1        Youssoufia ⵢⵓⵙⴼⵉⵢⴰ اليوسفية
# 2                    Esbiaat اسبيعات
# 3                 El Gantour الڭنطور
# 4  Safi - Ben Guerir أسفي - ابن جرير
#
#                                             geometry
# 0  MULTILINESTRING ((-8.55595 32.29040, -8.55577 ...
# 1  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 2  POLYGON ((-8.53836 32.27015, -8.53955 32.26697...
# 3  POLYGON ((-8.53174 32.22420, -8.52178 32.23045...
# 4  LINESTRING (-8.37457 32.27888, -8.37760 32.279...

# %%
import folium
from folium.plugins import MarkerCluster

# Assuming 'dff' is your GeoDataFrame containing the data

# Step 1: Get the centroid of the geometries and use it as the map center
map_center = [dff.geometry.centroid.y.mean(), dff.geometry.centroid.x.mean()]

# Step 2: Create the Folium map centered at the centroid
m = folium.Map(location=map_center, zoom_start=14)

# Step 3: Add the geometries to the map using MarkerCluster
marker_cluster = MarkerCluster().add_to(m)

# Step 4: Add each geometry as a marker to the MarkerCluster with a popup label
for idx, row in dff.iterrows():
    name = row['name']
    # Use the centroid of the geometry as the location for the marker
    lat, lon = row.geometry.centroid.y, row.geometry.centroid.x
    folium.Marker([lat, lon], popup=name).add_to(marker_cluster)

# Step 5: Display the map
m.save('maap.html')  # Save the map to an HTML file
m  # Display the map in Jupyter Notebook
# Out:
# C:\Users\Youcode\AppData\Local\Temp\ipykernel_56588\945823272.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   map_center = [dff.geometry.centroid.y.mean(), dff.geometry.centroid.x.mean()]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c857c86c08b1f68a158285c38234862b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c857c86c08b1f68a158285c38234862b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c857c86c08b1f68a158285c38234862b = L.map(
#                 &quot;map_c857c86c08b1f68a158285c38234862b&quot;,
#                 {
#                     center: [32.244340001398626, -8.537424192993926],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74acdc9ea4c2ea81871b3dab9b139a56 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c857c86c08b1f68a158285c38234862b);
#
#
#             var marker_cluster_116b14dcf696501ae7f80254a756a026 = L.markerClusterGroup(
#                 {}
#             );
#             map_c857c86c08b1f68a158285c38234862b.addLayer(marker_cluster_116b14dcf696501ae7f80254a756a026);
#
#
#             var marker_ed8a2da4d76c875df887eb7049964c8e = L.marker(
#                 [32.19700293421064, -8.571188877341564],
#                 {}
#             ).addTo(marker_cluster_116b14dcf696501ae7f80254a756a026);
#
#
#         var popup_7b12c17fa975d0759545c4d76f29ffcc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_90c4e8112827c22fa58e9ab6bbd8db7b = $(`&lt;div id=&quot;html_90c4e8112827c22fa58e9ab6bbd8db7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route Nationale 11&lt;/div&gt;`)[0];
#                 popup_7b12c17fa975d0759545c4d76f29ffcc.setContent(html_90c4e8112827c22fa58e9ab6bbd8db7b);
#
#
#
#         marker_ed8a2da4d76c875df887eb7049964c8e.bindPopup(popup_7b12c17fa975d0759545c4d76f29ffcc)
#         ;
#
#
#
#
#             var marker_e0e9e38c9fbf9653d14668727e57414f = L.marker(
#                 [32.24440789266327, -8.53325946041516],
#                 {}
#             ).addTo(marker_cluster_116b14dcf696501ae7f80254a756a026);
#
#
#         var popup_c68b562fae5da85b851de0b1fe804cb1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ca20b5e2bc25834b6208c7e6f4e7d5d = $(`&lt;div id=&quot;html_3ca20b5e2bc25834b6208c7e6f4e7d5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Youssoufia ⵢⵓⵙⴼⵉⵢⴰ اليوسفية&lt;/div&gt;`)[0];
#                 popup_c68b562fae5da85b851de0b1fe804cb1.setContent(html_3ca20b5e2bc25834b6208c7e6f4e7d5d);
#
#
#
#         marker_e0e9e38c9fbf9653d14668727e57414f.bindPopup(popup_c68b562fae5da85b851de0b1fe804cb1)
#         ;
#
#
#
#
#             var marker_3f2c71a69568b8b8898e3b65f2dd17dd = L.marker(
#                 [32.24165360257278, -8.54707830493086],
#                 {}
#             ).addTo(marker_cluster_116b14dcf696501ae7f80254a756a026);
#
#
#         var popup_dc21ff3f3bccf219d7f6e9c4c16d28c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a4895c40a31a4479625ff473a59a0905 = $(`&lt;div id=&quot;html_a4895c40a31a4479625ff473a59a0905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Esbiaat اسبيعات&lt;/div&gt;`)[0];
#                 popup_dc21ff3f3bccf219d7f6e9c4c16d28c3.setContent(html_a4895c40a31a4479625ff473a59a0905);
#
#
#
#         marker_3f2c71a69568b8b8898e3b65f2dd17dd.bindPopup(popup_dc21ff3f3bccf219d7f6e9c4c16d28c3)
#         ;
#
#
#
#
#             var marker_812d5815c71f67a512ba4b1006c342df = L.marker(
#                 [32.246641249418126, -8.52205424646547],
#                 {}
#             ).addTo(marker_cluster_116b14dcf696501ae7f80254a756a026);
#
#
#         var popup_9ee7868eece6023beebd72aaf8ade59c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c0445becd1d89ad9c90fc31d082b409 = $(`&lt;div id=&quot;html_0c0445becd1d89ad9c90fc31d082b409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El Gantour الڭنطور&lt;/div&gt;`)[0];
#                 popup_9ee7868eece6023beebd72aaf8ade59c.setContent(html_0c0445becd1d89ad9c90fc31d082b409);
#
#
#
#         marker_812d5815c71f67a512ba4b1006c342df.bindPopup(popup_9ee7868eece6023beebd72aaf8ade59c)
#         ;
#
#
#
#
#             var marker_1dcff0a13829837d602b756162bf0a6b = L.marker(

# %%
# Chargement des données géospatiales
df = gpd.read_file('map_points.geojson')
df.head()
# Out:
#                      name                   geometry
# 0                 Youcode  POINT (-8.52180 32.24755)
# 1              Gare train  POINT (-8.53454 32.24743)
# 2                  Eglise  POINT (-8.52766 32.24389)
# 3        Pharmacie Lahdir  POINT (-8.53237 32.24893)
# 4  Pharmacie Louis Gentil  POINT (-8.52834 32.24615)

# %%
import folium
from folium.plugins import MarkerCluster

# Step 1: Create a map centered at the mean of the points
m = folium.Map(location=[df.geometry.y.mean(), df.geometry.x.mean()], zoom_start=14)

# Step 2: Create a MarkerCluster to group the points
marker_cluster = MarkerCluster().add_to(m)

# Step 3: Add each point to the MarkerCluster with a popup label
for idx, row in df.iterrows():
    name = row['name']
    lat, lon = row.geometry.y, row.geometry.x
    folium.Marker([lat, lon], popup=name).add_to(marker_cluster)

# Step 4: Display the map
m.save('map_points.html')  # Save the map to an HTML file
m  # Display the map in Jupyter Notebook
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d98d7f3502831c5056944aa78542263 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d98d7f3502831c5056944aa78542263&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d98d7f3502831c5056944aa78542263 = L.map(
#                 &quot;map_6d98d7f3502831c5056944aa78542263&quot;,
#                 {
#                     center: [32.243844854948335, -8.534044301374548],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92956d41a492139d2518457a298712f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6d98d7f3502831c5056944aa78542263);
#
#
#             var marker_cluster_8b29a8e0d3c0fab87014aaae6c4507fa = L.markerClusterGroup(
#                 {}
#             );
#             map_6d98d7f3502831c5056944aa78542263.addLayer(marker_cluster_8b29a8e0d3c0fab87014aaae6c4507fa);
#
#
#             var marker_c0081f50657346cb62cb9a6f30bede2c = L.marker(
#                 [32.24754670596461, -8.521804293657084],
#                 {}
#             ).addTo(marker_cluster_8b29a8e0d3c0fab87014aaae6c4507fa);
#
#
#         var popup_be9c92dd23538d2165be279885841791 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd6c1d96fe035b012b93102761f70cf6 = $(`&lt;div id=&quot;html_dd6c1d96fe035b012b93102761f70cf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Youcode&lt;/div&gt;`)[0];
#                 popup_be9c92dd23538d2165be279885841791.setContent(html_dd6c1d96fe035b012b93102761f70cf6);
#
#
#
#         marker_c0081f50657346cb62cb9a6f30bede2c.bindPopup(popup_be9c92dd23538d2165be279885841791)
#         ;
#
#
#
#
#             var marker_08b90115afaa41a49b56eb125de0c194 = L.marker(
#                 [32.24742511509025, -8.534540710722297],
#                 {}
#             ).addTo(marker_cluster_8b29a8e0d3c0fab87014aaae6c4507fa);
#
#
#         var popup_1521140d8813eacb114bb23a514458f5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87a83e93a14cd709438cf8babe59178b = $(`&lt;div id=&quot;html_87a83e93a14cd709438cf8babe59178b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gare train&lt;/div&gt;`)[0];
#                 popup_1521140d8813eacb114bb23a514458f5.setContent(html_87a83e93a14cd709438cf8babe59178b);
#
#
#
#         marker_08b90115afaa41a49b56eb125de0c194.bindPopup(popup_1521140d8813eacb114bb23a514458f5)
#         ;
#
#
#
#
#             var marker_5350a9440660fb764bc77120e55261f4 = L.marker(
#                 [32.24389444948477, -8.527658547545968],
#                 {}
#             ).addTo(marker_cluster_8b29a8e0d3c0fab87014aaae6c4507fa);
#
#
#         var popup_80a2e988aa547bff8fc36ed81b03f252 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a57e1d29f4e5c2d371dfafe42f199b97 = $(`&lt;div id=&quot;html_a57e1d29f4e5c2d371dfafe42f199b97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eglise&lt;/div&gt;`)[0];
#                 popup_80a2e988aa547bff8fc36ed81b03f252.setContent(html_a57e1d29f4e5c2d371dfafe42f199b97);
#
#
#
#         marker_5350a9440660fb764bc77120e55261f4.bindPopup(popup_80a2e988aa547bff8fc36ed81b03f252)
#         ;
#
#
#
#
#             var marker_5ab16a52e64cf4670b489ad10f70c999 = L.marker(
#                 [32.248929704096554, -8.532369927192036],
#                 {}
#             ).addTo(marker_cluster_8b29a8e0d3c0fab87014aaae6c4507fa);
#
#
#         var popup_8f65a4dc0c785fbdbad29e21df026c53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3aa0a4f93a7de9116f745a3bfdfe4f8 = $(`&lt;div id=&quot;html_b3aa0a4f93a7de9116f745a3bfdfe4f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Lahdir&lt;/div&gt;`)[0];
#                 popup_8f65a4dc0c785fbdbad29e21df026c53.setContent(html_b3aa0a4f93a7de9116f745a3bfdfe4f8);
#
#
#
#         marker_5ab16a52e64cf4670b489ad10f70c999.bindPopup(popup_8f65a4dc0c785fbdbad29e21df026c53)
#         ;
#
#
#
#
#             var marker_d7db08f30ede2f223ea5dc4f6eb0d5f7 = L.marker(
#                 [32.24615448176418, -8.528

# %%
import geopandas as gpd
import folium
from folium.plugins import MarkerCluster
from geopy.distance import distance as geopy_distance

# Import the geospatial data
df = gpd.read_file('map_points.geojson')

# Get the user's input for the two points of interest
point_1 = input('Enter the name of the first point of interest: ')
point_2 = input('Enter the name of the second point of interest: ')

# Find the coordinates of the two points
coord_1 = (df[df['name'] == point_1].geometry.iloc[0].y, df[df['name'] == point_1].geometry.iloc[0].x)
coord_2 = (df[df['name'] == point_2].geometry.iloc[0].y, df[df['name'] == point_2].geometry.iloc[0].x)

# Calculate the distance between the two points
distance = geopy_distance(coord_1, coord_2).m

# Create a map centered at the mean of the points
m = folium.Map(location=[df.geometry.y.mean(), df.geometry.x.mean()], zoom_start=14)

# Create a MarkerCluster to group the points
marker_cluster = MarkerCluster().add_to(m)

# Add each point to the MarkerCluster with a popup label
for idx, row in df.iterrows():
    name = row['name']
    lat, lon = row.geometry.y, row.geometry.x
    folium.Marker([lat, lon], popup=name).add_to(marker_cluster)

# Add a straight line between the two points with distance as a tooltip
folium.PolyLine(
    locations=[coord_1, coord_2],
    color='red', weight=5,
    tooltip=f'Distance: {distance:.2f} meters'
).add_to(m)

# Display the map
m
# Out:
# Enter the name of the first point of interest: Youcode
# Enter the name of the second point of interest: Gare train
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f97600bda91322fdd6147410eb54bea7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f97600bda91322fdd6147410eb54bea7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f97600bda91322fdd6147410eb54bea7 = L.map(
#                 &quot;map_f97600bda91322fdd6147410eb54bea7&quot;,
#                 {
#                     center: [32.243844854948335, -8.534044301374548],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bfe29038d9aa505c7049a5822858656 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f97600bda91322fdd6147410eb54bea7);
#
#
#             var marker_cluster_5d32c8a45563b160e07d79bdedcf27ef = L.markerClusterGroup(
#                 {}
#             );
#             map_f97600bda91322fdd6147410eb54bea7.addLayer(marker_cluster_5d32c8a45563b160e07d79bdedcf27ef);
#
#
#             var marker_423f9c9b3c9cd7c2685f1cd1e10bb7f9 = L.marker(
#                 [32.24754670596461, -8.521804293657084],
#                 {}
#             ).addTo(marker_cluster_5d32c8a45563b160e07d79bdedcf27ef);
#
#
#         var popup_ea794e126139febb21f7370fbfcdb67a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8e0ca82c29702ceb33eef77a9d7c6eab = $(`&lt;div id=&quot;html_8e0ca82c29702ceb33eef77a9d7c6eab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Youcode&lt;/div&gt;`)[0];
#                 popup_ea794e126139febb21f7370fbfcdb67a.setContent(html_8e0ca82c29702ceb33eef77a9d7c6eab);
#
#
#
#         marker_423f9c9b3c9cd7c2685f1cd1e10bb7f9.bindPopup(popup_ea794e126139febb21f7370fbfcdb67a)
#         ;
#
#
#
#
#             var marker_f6445707d51894bb03fd23c49596d79c = L.marker(
#                 [32.24742511509025, -8.534540710722297],
#                 {}
#             ).addTo(marker_cluster_5d32c8a45563b160e07d79bdedcf27ef);
#
#
#         var popup_112b023529b2e7aa40e4a592c49db50c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_63d4e315c6eb5ccbfcb5bc8fdf63a3da = $(`&lt;div id=&quot;html_63d4e315c6eb5ccbfcb5bc8fdf63a3da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gare train&lt;/div&gt;`)[0];
#                 popup_112b023529b2e7aa40e4a592c49db50c.setContent(html_63d4e315c6eb5ccbfcb5bc8fdf63a3da);
#
#
#
#         marker_f6445707d51894bb03fd23c49596d79c.bindPopup(popup_112b023529b2e7aa40e4a592c49db50c)
#         ;
#
#
#
#
#             var marker_afaba1fd5322f395a9e5cdd9e661e370 = L.marker(
#                 [32.24389444948477, -8.527658547545968],
#                 {}
#             ).addTo(marker_cluster_5d32c8a45563b160e07d79bdedcf27ef);
#
#
#         var popup_6f44192aa607e4ab0072f34f5e4eece0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5611e99e8ce14543a7e57129792b91e2 = $(`&lt;div id=&quot;html_5611e99e8ce14543a7e57129792b91e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Eglise&lt;/div&gt;`)[0];
#                 popup_6f44192aa607e4ab0072f34f5e4eece0.setContent(html_5611e99e8ce14543a7e57129792b91e2);
#
#
#
#         marker_afaba1fd5322f395a9e5cdd9e661e370.bindPopup(popup_6f44192aa607e4ab0072f34f5e4eece0)
#         ;
#
#
#
#
#             var marker_c287d09fd10ad57628ae9b5f742999d3 = L.marker(
#                 [32.248929704096554, -8.532369927192036],
#                 {}
#             ).addTo(marker_cluster_5d32c8a45563b160e07d79bdedcf27ef);
#
#
#         var popup_25e8fd3ff7acbe45673d557acb0ec0d1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba185411b817e31864dabc5d476f38e9 = $(`&lt;div id=&quot;html_ba185411b817e31864dabc5d476f38e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Pharmacie Lahdir&lt;/div&gt;`)[0];
#                 popup_25e8fd3ff7acbe45673d557acb0ec0d1.setContent(html_ba185411b817e31864dabc5d476f38e9);
#
#
#
#         marker_c287d09fd10ad57628ae9b5f742999d3.bindPopup(popup_25e8fd3ff7acbe45673d557acb0ec0d1)
#         ;
#
#
#
#
#             var marker_a7f582a1f449dfcd7ec0fb1bab553683 = L.marker(
#                 [32.24615448176418, -8.528
